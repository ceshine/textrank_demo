# %%
import sys
import re
import os
from pathlib import Path
from collections import namedtuple

import numpy as np

# %%
LASER_PATH = Path("..")
sys.path.append(str(LASER_PATH.resolve()))
os.environ["LASER"] = str(LASER_PATH.resolve())

MODEL_PATH = Path("../models")
DATA_PATH = Path("../data/tatoeba/v1/")

from source.shortcuts import text_file_pipeline
from source.lib.indexing import IndexSearchMultiple

# %%
data_en, index_en = text_file_pipeline(
    "en",
    str(DATA_PATH / "tatoeba.cmn-eng.eng"),
    str(MODEL_PATH / "bilstm.93langs.2018-12-26.pt"), 
    str(MODEL_PATH / "93langs.fcodes"),
    use_cpu=False,
    returns="index",
    batch_size=20
)
data_zh, index_zh = text_file_pipeline(
    "zh",
    str(DATA_PATH / "tatoeba.cmn-eng.cmn"),
    str(MODEL_PATH / "bilstm.93langs.2018-12-26.pt"), 
    str(MODEL_PATH / "93langs.fcodes"),
    use_cpu=False,
    returns="index",
    batch_size=20
)
# Out:
#  - Tokenizer: tatoeba.cmn-eng.eng in language en
#  - fast BPE: processing token
#  - Encoder: bpe to enc
#  - Encoder: 1000 sentences in 4s
#  - embedding: /tmp/tmprlouhyym/enc 1000 examples of dim 1024
#  - creating FAISS index
#  - Tokenizer: tatoeba.cmn-eng.cmn in language zh
#  - fast BPE: processing token
#  - Encoder: bpe to enc
#  - Encoder: 1000 sentences in 4s
#  - embedding: /tmp/tmphoiz6jwm/enc 1000 examples of dim 1024
#  - creating FAISS index

# %% [markdown]
# ## Evaluation

# %%
err = IndexSearchMultiple(
    [data_en, data_zh], [index_en, index_zh], verbose=True, texts=None)
# Out:
# Calculating similarity error (indices):
#  - similarity error lang_1=>lang_2  4.10%
#  - similarity error lang_2=>lang_1  5.00%

# %% [markdown]
# ### Error Analysis

# %% [markdown]
# Read in the documents:

# %%
documents = {}
for lang in ("eng", "cmn"):
    with open(DATA_PATH / f"tatoeba.cmn-eng.{lang}") as fin:
        documents[lang] = list(fin.readlines())
print(len(documents["eng"]), len(documents["cmn"]))
# Out:
# 1000 1000

# %% [markdown]
# #### English to Chinese Mandarin

# %%
_, matched_indices = index_zh.search(data_en, 1)
matched_indices.shape
# Out:
# (1000, 1)

# %%
sum([x == i for i, x in enumerate(matched_indices[:, 0])])
# Out:
# 959

# %%
for idx in np.where([x != i for i, x in enumerate(matched_indices[:, 0])])[0]:
    print(
        "source:  ", documents["eng"][idx].strip() + "\n",
        "predict: ", documents["cmn"][matched_indices[idx, 0]].strip() + "\n",
        "correct: ", documents["cmn"][idx].strip() + "\n", sep=""
    )
# Out:
# source:  I'm at a loss for words.
# predict: 我興奮得說不出話來。
# correct: 我不知道應該說什麼才好。
#
# source:  I just don't know what to say.
# predict: 我不知道應該說什麼才好。
# correct: 我只是不知道應該說什麼而已……
#
# source:  You should sleep.
# predict: 你应该睡觉。
# correct: 你應該去睡覺了吧。
#
# source:  So fuckin' what.
# predict: 這是什麼啊？
# correct: 那又怎樣?
#
# source:  I don't like him any more than he likes me.
# predict: 我也不喜欢他。
# correct: 我們之間已經沒有感情了。
#
# source:  A guest should not try to make himself superior to the host.
# predict: 没有欲望就等于拥有。
# correct: 强宾不压主。
#
# source:  Something can't get out of hand.
# predict: 这个问题不能解决。
# correct: 爱不释手
#
# source:  She was beside herself with joy.
# predict: 她陶醉在幸福裡。
# correct: 她欣喜若狂。
#
# source:  I am the fastest runner.
# predict: 我是最快的跑者。
# correct: 我是跑得最快的人。
#
# source:  I am sorry to trouble you.
# predict: 我很抱歉打擾你了。
# correct: 我很抱歉給你添麻煩了。
#
# source:  I am content with my job.
# predict: 我很滿意我的工作。
# correct: 我對我的工作感到滿意。
#
# source:  He is an easy mark at cards.
# predict: 他是一個撲克牌高手。
# correct: 他打牌很容易被騙。
#
# source:  You can see that the architect paid scrupulous attention to detail.
# predict: 他的演講吸引了我們的注意。
# correct: 這位建築師顯然是一位無微不至的建築師。
#
# source:  I am constantly forgetting names.
# predict: 我经常忘记别人的名字。
# correct: 我經常忘記別人的名字。
#
# source:  He's crazy about you.
# predict: 他向我大發脾氣。
# correct: 他被你迷住了。
#
# source:  I am from Shikoku.
# predict: 我會彈蕭邦。
# correct: 我來自四國。
#
# source:  Appetite comes with eating.
# predict: 没有欲望就等于拥有。
# correct: 贪得无厌。
#
# source:  I do not like him either.
# predict: 我也不喜欢他。
# correct: 我也不喜欢她。
#
# source:  You'll be able to see the differences very easily.
# predict: 您很容易就能看出区别。
# correct: 你们很容易就能看出区别。
#
# source:  Rub salt in the wound.
# predict: 把肉切成薄片。
# correct: 按住痛处。
#
# source:  Don't worry about it!
# predict: 不要擔心。
# correct: 你不要着急。
#
# source:  I can do it without her help.
# predict: 沒有她的幫助我做不到。
# correct: 沒有她的幫忙我也能做。
#
# source:  I'm really glad you're here.
# predict: 我很高興我在那裡。
# correct: 你能来我真高兴。
#
# source:  We must have something to live for.
# predict: 没有我们能还做的事。
# correct: 人生在世，總要有目標和追求的。
#
# source:  It's in times like these that the character of a person becomes apparent.
# predict: 我觉得像这样句子听起来更自然。
# correct: 路遙知馬力，日久見人心。
#
# source:  Are you looking for work?
# predict: 你在找工作吗？
# correct: 你是在找工作吗？
#
# source:  You were duped by him.
# predict: 他被你迷住了。
# correct: 他讓你上當。
#
# source:  There weren't any cats.
# predict: 那儿没有猫。
# correct: 以前那里没有过猫。
#
# source:  You'd better see a doctor.
# predict: 我父亲是个大夫。
# correct: 你还是去看病吧。
#
# source:  Let's watch TV.
# predict: 我們正在看電視。
# correct: 看电视吧。
#
# source:  I held my breath in excitement.
# predict: 我感覺到自己的心在劇烈地跳動。
# correct: 我興奮得說不出話來。
#
# source:  The frying pan is rusty.
# predict: 蛋黃是黃色的。
# correct: 鍋銹掉了。
#
# source:  Open up your mind.
# predict: 打開你的心胸。
# correct: 敞開你的心扉。
#
# source:  Catch as catch can.
# predict: 按住痛处。
# correct: 做多少算多少。
#
# source:  You should go to bed.
# predict: 你應該去睡覺了吧。
# correct: 你应该睡觉。
#
# source:  He went to Italy in order to study music.
# predict: 他去義大利的目的是學習音樂。
# correct: 為了研讀音樂他去了義大利。
#
# source:  I always have trouble remembering names.
# predict: 我總是忘記別人的名字。
# correct: 我经常忘记别人的名字。
#
# source:  She writes beautifully.
# predict: 她的写作很好。
# correct: 她的笔迹漂亮极了。
#
# source:  I am blessed with good health.
# predict: 我很幸運有健康的身體。
# correct: 上帝賜予我健康的身體。
#
# source:  So be it.
# predict: 好，定了。
# correct: 行。
#
# source:  I arrived in London.
# predict: 我在伦敦。
# correct: 我到達倫敦了。

# %%
_, matched_indices = index_en.search(data_zh, 1)
matched_indices.shape
# Out:
# (1000, 1)

# %% [markdown]
# #### Chinese to English Mandarin

# %%
for idx in np.where([x != i for i, x in enumerate(matched_indices[:, 0])])[0]:
    print(
        "source:  ", documents["cmn"][idx].strip() + "\n",
        "predict: ", documents["eng"][matched_indices[idx, 0]].strip() + "\n",
        "correct: ", documents["eng"][idx].strip() + "\n", sep=""
    )
# Out:
# source:  我不知道應該說什麼才好。
# predict: I just don't know what to say.
# correct: I'm at a loss for words.
#
# source:  你應該去睡覺了吧。
# predict: You should go to bed.
# correct: You should sleep.
#
# source:  那又怎樣?
# predict: What is this?
# correct: So fuckin' what.
#
# source:  我們之間已經沒有感情了。
# predict: It would be better for both of us not to see each other anymore.
# correct: I don't like him any more than he likes me.
#
# source:  我不同意你這個觀點。
# predict: I agree with your opinion.
# correct: I can't go along with you on that point.
#
# source:  强宾不压主。
# predict: A lion is strong.
# correct: A guest should not try to make himself superior to the host.
#
# source:  我不了解他。
# predict: I don't understand you.
# correct: I can't figure him out.
#
# source:  爱不释手
# predict: I miss you.
# correct: Something can't get out of hand.
#
# source:  她欣喜若狂。
# predict: She is sick.
# correct: She was beside herself with joy.
#
# source:  我是最快的跑者。
# predict: I am the fastest runner.
# correct: I'm the fastest runner.
#
# source:  我很抱歉打擾你了。
# predict: I am sorry to trouble you.
# correct: I'm sorry to trouble you.
#
# source:  他打牌很容易被騙。
# predict: He is very good at poker.
# correct: He is an easy mark at cards.
#
# source:  我全身酸痛。
# predict: I held my breath in excitement.
# correct: I ache all over.
#
# source:  這位建築師顯然是一位無微不至的建築師。
# predict: The man turned out to be a private detective.
# correct: You can see that the architect paid scrupulous attention to detail.
#
# source:  我經常忘記別人的名字。
# predict: I'm always forgetting people's names.
# correct: I am constantly forgetting names.
#
# source:  他每天刮鬍子。
# predict: I wash my face every morning.
# correct: He shaves daily.
#
# source:  我生性樂觀。
# predict: I am an optimist by nature.
# correct: I'm an optimist by nature.
#
# source:  他被你迷住了。
# predict: You were duped by him.
# correct: He's crazy about you.
#
# source:  我來自四國。
# predict: I arrived in London.
# correct: I am from Shikoku.
#
# source:  我很滿意我的工作。
# predict: I am content with my job.
# correct: I'm satisfied with my work.
#
# source:  贪得无厌。
# predict: He is no fool.
# correct: Appetite comes with eating.
#
# source:  我連你叫什麼都不知道。
# predict: I just don't know what to say.
# correct: I don't even know what you are called, mate.
#
# source:  我也不喜欢他。
# predict: I do not like him either.
# correct: I don't like it, either.
#
# source:  这是在吵什么呀？
# predict: What is this?
# correct: What's the commotion?
#
# source:  你们很容易就能看出区别。
# predict: You'll be able to see the difference very easily.
# correct: You'll be able to see the differences very easily.
#
# source:  我們還是不要再見面了。
# predict: I can't meet you.
# correct: It would be better for both of us not to see each other anymore.
#
# source:  他是个无可救药的家伙。
# predict: He is an aggressive person.
# correct: He's a hopeless case.
#
# source:  按住痛处。
# predict: I ache all over.
# correct: Rub salt in the wound.
#
# source:  你不要着急。
# predict: Don't be worried.
# correct: Don't worry about it!
#
# source:  反正已經太晚了。
# predict: It's too late now.
# correct: It's too late, anyhow.
#
# source:  人生在世，總要有目標和追求的。
# predict: Who searches, finds.
# correct: We must have something to live for.
#
# source:  路遙知馬力，日久見人心。
# predict: Refugees poured in from all over the country.
# correct: It's in times like these that the character of a person becomes apparent.
#
# source:  你是在找工作吗？
# predict: Are you looking for a job?
# correct: Are you looking for work?
#
# source:  他讓你上當。
# predict: He swindled her.
# correct: You were duped by him.
#
# source:  以前那里没有过猫。
# predict: There was no cat.
# correct: There weren't any cats.
#
# source:  你该学他。
# predict: He swindled her.
# correct: You should learn from his example.
#
# source:  好，定了。
# predict: So be it.
# correct: All right. It's a deal.
#
# source:  你还是去看病吧。
# predict: You should go to bed.
# correct: You'd better see a doctor.
#
# source:  鍋銹掉了。
# predict: The box is broken.
# correct: The frying pan is rusty.
#
# source:  我應該不能再見到他了。
# predict: I can't meet you.
# correct: There is little chance of my meeting him again.
#
# source:  敞開你的心扉。
# predict: Open your heart.
# correct: Open up your mind.
#
# source:  做多少算多少。
# predict: How much is this tie?
# correct: Catch as catch can.
#
# source:  他們正在聊天。
# predict: There's always someone talking.
# correct: They are having a chat.
#
# source:  他向我大發脾氣。
# predict: He's crazy about you.
# correct: He entirely lost his temper with me.
#
# source:  你应该睡觉。
# predict: You should sleep.
# correct: You should go to bed.
#
# source:  他法语说得很好。
# predict: I am good at speaking English.
# correct: He is fluent in French.
#
# source:  他潛心研究音樂。
# predict: He is playing music.
# correct: He applied himself to the study of music.
#
# source:  我经常忘记别人的名字。
# predict: I'm always forgetting people's names.
# correct: I always have trouble remembering names.
#
# source:  她的笔迹漂亮极了。
# predict: Her writing is very good.
# correct: She writes beautifully.
#
# source:  我到達倫敦了。
# predict: I am in London.
# correct: I arrived in London.
